# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data (2).csv")
df.sample(10)
# Out:
#     Unnamed: 0        Brand                 Model  AccelSec  TopSpeed_KmH  \
# 65          65     Porsche         Taycan 4S Plus       4.0           250
# 25          25  Volkswagen                  ID.4        7.5           160
# 19          19        Mini             Cooper SE        7.3           150
# 95          95  Volkswagen   ID.3 Pro Performance       7.3           160
# 74          74        Sono                  Sion        9.0           140
# 48          48   Lightyear                   One       10.0           150
# 1            1  Volkswagen              ID.3 Pure      10.0           160
# 16          16     Porsche         Taycan Turbo S       2.8           260
# 93          93      Nissan    Ariya e-4ORCE 87kWh       5.7           200
# 6            6  Volkswagen                e-Golf        9.6           150
#
#     Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge PowerTrain  \
# 65       425              197             890         Yes        AWD
# ...

# %%
df.shape
# Out:
# (103, 15)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       103 non-null    int64
#  1   Brand            103 non-null    object
#  2   Model            103 non-null    object
#  3   AccelSec         103 non-null    float64
#  4   TopSpeed_KmH     103 non-null    int64
#  5   Range_Km         103 non-null    int64
#  6   Efficiency_WhKm  103 non-null    int64
#  7   FastCharge_KmH   103 non-null    int64
#  8   RapidCharge      103 non-null    object
#  9   PowerTrain       103 non-null    object
#  10  PlugType         103 non-null    object
#  11  BodyStyle        103 non-null    object
#  12  Segment          103 non-null    object
#  13  Seats            103 non-null    int64
#  14  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 12.2+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'], inplace = True)

# %%
df.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm  FastCharge_KmH  \
# count  103.000000    103.000000  103.000000       103.000000      103.000000
# mean     7.396117    179.194175  338.786408       189.165049      444.271845
# std      3.017430     43.573030  126.014444        29.566839      203.949253
# min      2.100000    123.000000   95.000000       104.000000      170.000000
# 25%      5.100000    150.000000  250.000000       168.000000      260.000000
# 50%      7.300000    160.000000  340.000000       180.000000      440.000000
# 75%      9.000000    200.000000  400.000000       203.000000      555.000000
# max     22.400000    410.000000  970.000000       273.000000      940.000000
#
#             Seats      PriceEuro
# count  103.000000     103.000000
# mean     4.883495   55811.563107
# std      0.795834   34134.665280
# min      2.000000   20129.000000
# 25%      5.000000   34429.500000
# 50%      5.000000   45000.000000
# 75%      5.000000   65000.000000
# ...

# %%
df['AccelSec'].plot(kind='kde')
plt.show()

# %%
df['Range_Km'].plot(kind='kde')
plt.show()

# %%
df['Efficiency_WhKm'].plot(kind='kde')
plt.show()

# %%
df['FastCharge_KmH'].plot(kind='kde')
plt.show()

# %%
df['Seats'].plot(kind='kde')
plt.show()

# %%
df['PriceEuro'].plot(kind='kde')
plt.show()

# %%
df['Brand'].value_counts().plot(kind='barh',figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
df['RapidCharge'].value_counts().plot(kind='barh',figsize=(9,6))
# Out:
# <AxesSubplot:>

# %%
df['PowerTrain'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='PowerTrain'>

# %%
df['PlugType'].value_counts().plot(kind='barh',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
df['BodyStyle'].value_counts().plot(kind='barh',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
df['Segment'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Segment'>

# %%
plt.figure(figsize=(9,6))
sns.barplot(x=df['RapidCharge'],y=df['PriceEuro'])
# Out:
# <AxesSubplot:xlabel='RapidCharge', ylabel='PriceEuro'>

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x=df['PlugType'],y=df['PriceEuro'])
# Out:
# <AxesSubplot:xlabel='PlugType', ylabel='PriceEuro'>

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x=df['BodyStyle'],y=df['PriceEuro'])
# Out:
# <AxesSubplot:xlabel='BodyStyle', ylabel='PriceEuro'>

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x=df['Seats'],y=df['PriceEuro'])
# Out:
# <AxesSubplot:xlabel='Seats', ylabel='PriceEuro'>

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x=df['AccelSec'],y=df['TopSpeed_KmH'])
plt.title("AccelSec VS Top Speed KMH ScatterPlot")
plt.show()

# %%
corr_matrix = df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Efficiency_WhKm', y='Range_Km', data=df, hue='Segment')
plt.title("Efficiency vs. Range")
plt.xlabel("Efficiency (Wh/Km)")
plt.ylabel("Range (Km)")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Segment', y='PriceEuro', data=df)
plt.title("Price Distribution by Segment")
plt.xticks(rotation=45)
plt.ylabel("Price (Euro)")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='PlugType', data=df)
plt.title("Distribution of Charging Plug Types")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Segment', y='FastCharge_KmH', data=df, ci=None)
plt.title("Average Fast Charging Speed by Segment")
plt.xticks(rotation=45)
plt.ylabel("Fast Charging Speed (Km/H)")
plt.show()

# %%
data = pd.get_dummies(df, columns=['Brand', 'BodyStyle', 'Segment', 'PowerTrain', 'PlugType'])

# %%
from sklearn.cluster import KMeans
features = data[['AccelSec', 'TopSpeed_KmH', 'Range_Km', 'Efficiency_WhKm', 'FastCharge_KmH', 'Seats', 'PriceEuro']]
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(features)
    inertia.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal Clusters')
plt.show()

# %%
num_clusters = 4
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
data['Cluster'] = kmeans.fit_predict(features)

# %%
cluster_means = data.groupby('Cluster').mean()
for i in range(num_clusters):
    print(f"Cluster {i+1}:\n{cluster_means.iloc[i]}\n{'-'*40}")
# Out:
# Cluster 1:
# AccelSec                     5.735484
# TopSpeed_KmH               195.548387
# Range_Km                   399.677419
# Efficiency_WhKm            210.096774
# FastCharge_KmH             545.161290
#                               ...
# PowerTrain_RWD               0.129032
# PlugType_Type 1 CHAdeMO      0.000000
# PlugType_Type 2              0.032258
# PlugType_Type 2 CCS          0.935484
# PlugType_Type 2 CHAdeMO      0.032258
# Name: 0, Length: 64, dtype: float64
# ----------------------------------------
# Cluster 2:
# AccelSec                     4.32
# TopSpeed_KmH               266.00
# Range_Km                   539.00
# Efficiency_WhKm            193.00
# FastCharge_KmH             764.00
#                             ...
# PowerTrain_RWD               0.00
# PlugType_Type 1 CHAdeMO      0.00
# PlugType_Type 2              0.00
# PlugType_Type 2 CCS          1.00
# PlugType_Type 2 CHAdeMO      0.00
# Name: 1, Length: 64, dtype: float64
# ...
